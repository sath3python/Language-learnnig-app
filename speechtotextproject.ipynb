# %%
import os
from gtts import gTTS
import time
from translate import Translator
import os
import azure.cognitiveservices.speech as speechsdk
import speech_recognition as sr
Text = "Welcome to the Language learning app in python with the help of speech to text."

print("please wait...processing")
TTS = gTTS(text=Text, lang='en')

# Save to mp3 in current dir.
TTS.save("voice.mp3")

# Plays the mp3 using the default app on your system
# that is linked to mp3s.
os.system("start voice.mp3")
time.sleep(4)
Text = "This app supports 53 languages. But for this project, only 5 languages are taken"

print("please wait...processing")
TTS = gTTS(text=Text, lang='en')

# Save to mp3 in current dir.
TTS.save("voice1.mp3")

# Plays the mp3 using the default app on your system
# that is linked to mp3s.
os.system("start voice1.mp3")
time.sleep(5)
print("1=English\n2=German\n3=Spanish\n4=French\n5=Italian")
Text = "Please enter the number as per assignment available on the screen to translate into the language you want "
TTS = gTTS(text=Text, lang='en')
TTS.save("voicea.mp3")
os.system("start voicea.mp3")
lang=int(input("Please enter the number to translate the laguage you want"))
time.sleep(4)
if(lang==1):
    print("You have chosen English.Thus, no translation needed")
    Text = "You have chosen English.Thus, no translation needed"

    #print("please wait...processing")
    TTS = gTTS(text=Text, lang='en')

# Save to mp3 in current dir.
    TTS.save("voice2.mp3")

# Plays the mp3 using the default app on your system
# that is linked to mp3s.
    os.system("start voice2.mp3")
    time.sleep(7)
    speech_key,service_region="fbcc88a24cdb4f63957a8e777c6a98e0","westus"
    setting=speechsdk.SpeechConfig(subscription=speech_key,region=service_region)
    speech_recognizer=speechsdk.SpeechRecognizer(speech_config=setting)
    print("MIC ON.. say something ...")
    results=speech_recognizer.recognize_once()
    print("This is what you said...",results.text)
    a=results.text
    def l(a):
        return(a)
        quit()
    translator= Translator(to_lang="English")
    translation = translator.translate(l(a))
    print (translation)
    Text = translation
    TTS = gTTS(text=Text, lang='nl')
    TTS.save("voice16.mp3")
    os.system("start voice16.mp3")
    
elif(lang==2):
    print("You have chosen German for translation")
    Text = "You have chosen German for translation"
    TTS = gTTS(text=Text, lang='en')
    TTS.save("voice3.mp3")
    os.system("start voice3.mp3")
    time.sleep(7)
    print("Please say something you want to translate when the mic is on")
    Text = "Please say something you want to translate when the mic is on"
    TTS = gTTS(text=Text, lang='en')
    TTS.save("voice8.mp3")
    os.system("start voice8.mp3")
    time.sleep(5)
    speech_key,service_region="fbcc88a24cdb4f63957a8e777c6a98e0","westus"
    setting=speechsdk.SpeechConfig(subscription=speech_key,region=service_region)
    speech_recognizer=speechsdk.SpeechRecognizer(speech_config=setting)
    print("MIC ON.. say something ...")
    results=speech_recognizer.recognize_once()
    print("This is what you said...",results.text)
    a=results.text
    def l(a):
        return(a)
        quit()
    translator= Translator(to_lang="German")
    translation = translator.translate(l(a))
    print (translation)
    Text = translation
    for i in range(0,2):
        TTS = gTTS(text=Text, lang='nl')
        TTS.save("voice12.mp3")
        os.system("start voice12.mp3")
        i=i+1
        time.sleep(8)
elif(lang==3):
    print("You have chosen Spanish for translation")
    Text = "You have chosen Spanish for translation"
    TTS = gTTS(text=Text, lang='en')
    TTS.save("voice4.mp3")
    os.system("start voice4.mp3")
    time.sleep(4)
    print("Please say something you want to translate when the mic is on")
    Text = "Please say something you want to translate when the mic is on"
    TTS = gTTS(text=Text, lang='en')
    TTS.save("voice9.mp3")
    os.system("start voice9.mp3")
    time.sleep(5)
    speech_key,service_region="fbcc88a24cdb4f63957a8e777c6a98e0","westus"
    setting=speechsdk.SpeechConfig(subscription=speech_key,region=service_region)
    speech_recognizer=speechsdk.SpeechRecognizer(speech_config=setting)
    print("MIC ON.. say something ...")
    results=speech_recognizer.recognize_once()
    print("This is what you said...",results.text)
    a=results.text
    def l(a):
        return(a)
        quit()
    translator= Translator(to_lang="Spanish")
    translation = translator.translate(l(a))
    print (translation)
    Text = translation
    for i in range(0,2):
        TTS = gTTS(text=Text, lang='es')
        TTS.save("voice13.mp3")
        os.system("start voice13.mp3")
        i=i+1
        time.sleep(8)
elif(lang==4):
    print("you have chosen French for translation")
    Text = "You have chosen French for translation"
    TTS = gTTS(text=Text, lang='en')
    TTS.save("voice5.mp3")
    os.system("start voice5.mp3")
    time.sleep(4)
    print("Please say something you want to translate when the mic is on")
    Text = "Please say something you want to translate when the mic is on"
    TTS = gTTS(text=Text, lang='en')
    TTS.save("voice10.mp3")
    os.system("start voice10.mp3")
    time.sleep(5)
    speech_key,service_region="fbcc88a24cdb4f63957a8e777c6a98e0","westus"
    setting=speechsdk.SpeechConfig(subscription=speech_key,region=service_region)
    speech_recognizer=speechsdk.SpeechRecognizer(speech_config=setting)
    print("MIC ON.. say something ...")
    results=speech_recognizer.recognize_once()
    print("This is what you said...",results.text)
    a=results.text
    def l(a):
        return(a)
        quit()
    translator= Translator(to_lang="French")
    translation = translator.translate(l(a))
    print (translation)
    Text = translation
    for i in range(0,2):
        TTS = gTTS(text=Text, lang='fr')
        TTS.save("voice14.mp3")
        os.system("start voice14.mp3")
        i=i+1
        time.sleep(8)
elif(lang==5):
    prints("you have chosen Italian for translation")
    Text = "You have chosen Italian for translation"
    TTS = gTTS(text=Text, lang='en')
    TTS.save("voice6.mp3")
    os.system("start voice6.mp3")
    time.sleep(4)
    print("Please say something you want to translate when the mic is on")
    Text = "Please say something you want to translate when the mic is on"
    TTS = gTTS(text=Text, lang='en')
    TTS.save("voice11.mp3")
    os.system("start voice11.mp3")
    time.sleep(5)
    speech_key,service_region="fbcc88a24cdb4f63957a8e777c6a98e0","westus"
    setting=speechsdk.SpeechConfig(subscription=speech_key,region=service_region)
    speech_recognizer=speechsdk.SpeechRecognizer(speech_config=setting)
    print("MIC ON.. say something ...")
    results=speech_recognizer.recognize_once()
    print("This is what you said...",results.text)
    a=results.text
    def l(a):
        return(a)
        quit()
    translator= Translator(to_lang="Italy")
    translation = translator.translate(l(a))
    print (translation)
    Text = translation
    for i in range(0,2):
        TTS = gTTS(text=Text, lang='it')
        TTS.save("voice15.mp3")
        os.system("start voice15.mp3")
        i=i+1
        time.sleep(8)
else:
    print("Please enter from one to five in number")
    Text = "Please enter from one to five in number"
    TTS = gTTS(text=Text, lang='en')
    TTS.save("voice7.mp3")
    os.system("start voice7.mp3")
# Out:
# please wait...processing
# please wait...processing
# 1=English
# 2=German
# 3=Spanish
# 4=French
# 5=Italian
# Please enter the number to translate the laguage you want3
# You have chosen Spanish for translation
# Please say something you want to translate when the mic is on
# MIC ON.. say something ...
# This is what you said... Good morning, how are you?
# Ahora que no estás, que no te puedo ver

# %%
import os
from gtts import gTTS

Text = "This app supports 53 languages. But for this project, only 5 languages are taken"

print("please wait...processing")
TTS = gTTS(text=Text, lang='en')

# Save to mp3 in current dir.
TTS.save("voice1.mp3")

# Plays the mp3 using the default app on your system
# that is linked to mp3s.
os.system("start voice1.mp3")
# Out:
# please wait...processing
# 0

# %%
print("1=English\n2=German\n3=Spanish\n4=French\n5=Italian")
Text = "Please enter the number as per assignment available on the screen to translate into the language you want "
TTS = gTTS(text=Text, lang='en')
TTS.save("voicea.mp3")
os.system("start voicea.mp3")
lang=int(input("Please enter the number to translate the laguage you want"))
time.sleep(4)
if(lang==1):
    print("You have chosen English.Thus, no translation need")
    Text = "You have chosen English.Thus, no translation need"

    #print("please wait...processing")
    TTS = gTTS(text=Text, lang='en')

# Save to mp3 in current dir.
    TTS.save("voice2.mp3")

# Plays the mp3 using the default app on your system
# that is linked to mp3s.
    os.system("start voice2.mp3")
elif(lang==2):
    print("You have chosen German for translation")
    Text = "You have chosen German for translation"
    TTS = gTTS(text=Text, lang='en')
    TTS.save("voice3.mp3")
    os.system("start voice3.mp3")
elif(lang==3):
    print("You have chosen Spanish for translation")
    Text = "You have chosen Spanish for translation"
    TTS = gTTS(text=Text, lang='en')
    TTS.save("voice4.mp3")
    os.system("start voice4.mp3")
elif(lang==4):
    print("you have chosen French for translation")
    Text = "You have chosen French for translation"
    TTS = gTTS(text=Text, lang='en')
    TTS.save("voice5.mp3")
    os.system("start voice5.mp3")
elif(lang==5):
    prints("you have chosen Italian for translation")
    Text = "You have chosen Italian for translation"
    TTS = gTTS(text=Text, lang='en')
    TTS.save("voice6.mp3")
    os.system("start voice6.mp3")
else:
    print("Please enter from one to five in number")
    Text = "Please enter from one to five in number"
    TTS = gTTS(text=Text, lang='en')
    TTS.save("voice7.mp3")
    os.system("start voice7.mp3")
# Out:
# 1=English
# 2=German
# 3=Spanish
# 4=French
# 5=Italian
# Please enter the number to translate the laguage you want4
# you have chosen French for translation

# %%
from translate import Translator
import os
import azure.cognitiveservices.speech as speechsdk
import speech_recognition as sr
print("Please say something you want to translate")
Text = "Please say something you want to translate"
TTS = gTTS(text=Text, lang='en')
TTS.save("voice8.mp3")
os.system("start voice8.mp3")
time.sleep(5)
speech_key,service_region="fbcc88a24cdb4f63957a8e777c6a98e0","westus"
setting=speechsdk.SpeechConfig(subscription=speech_key,region=service_region)
speech_recognizer=speechsdk.SpeechRecognizer(speech_config=setting)
print("MIC ON.. say something ...")
results=speech_recognizer.recognize_once()
print("This is what you said...",results.text)
a=results.text
print(a)
def l(a):
    return(a)
    quit()
translator= Translator(to_lang="German")
translation = translator.translate(l(a))
print (translation)

# %%
from translate import Translator
def text(a):
    a=result.text
    return(a)
    quit()
if(lang==1):
    print("As you have selected English. No translation")
elif(lang==2):    
    translator= Translator(to_lang="German")
    translation = translator.translate(text(a))
    print (translation)
elif(lang==3):    
    translator= Translator(to_lang="Spanish")
    translation = translator.translate("Good Morning!")
    print (translation)
elif(lang==4):    
    translator= Translator(to_lang="French")
    translation = translator.translate("Good Morning!")
    print (translation)
elif(lang==5):    
    translator= Translator(to_lang="Italian")
    translation = translator.translate("Good Morning!")
    print (translation)

# %%
import numpy as np
import time
import sounddevice as sd
myarray= "welcome.mp3"
sd.play(myarray)
time.sleep(10)
sd.stop()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-e37cd22b9045> in <module>
#       2 import time
#       3 import sounddevice as sd
# ----> 4 myarray= welcome.mp3
#       5 sd.play(myarray)
#       6 time.sleep(10)
#
# NameError: name 'welcome' is not defined
